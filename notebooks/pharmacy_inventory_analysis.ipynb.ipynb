# %%
import pandas as pd

# Load dataset

df = pd.read_excel(C:\Users\sarah25\Downloads\pharmacy_inventory_data.xlsx)

# Preview dataset

df.head()
# Out:
#   Cell In[4], line 5
#     df = pd.read_excel(C:\Users\sarah25\Downloads\pharmacy_inventory_data.xlsx)
#                         ^
# SyntaxError: invalid syntax
